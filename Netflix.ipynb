# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\sudhi\\Downloads\\titles.csv")
df
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     King Arthur, accompanied by his squire, recrui...          1975
# 3     Brian Cohen is an average young Jewish man, bu...          1979
# 4     12-year-old Regan MacNeil begins to adapt an e...          1973
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# 2                   PG       91              ['comedy', 'fantasy']
# 3                    R       94                         ['comedy']
# 4                    R      133                         ['horror']
# ...                ...      ...                                ...
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']      1.0         NaN         NaN         NaN
# 1                  ['US']      NaN   tt0075314         8.3    795222.0
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 3                  ['GB']      NaN   tt0079470         8.0    392419.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# ...                   ...      ...         ...         ...         ...
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 1              27.612         8.2
# 2              18.216         7.8
# 3              17.505         7.8
# 4              95.337         7.7
# ...               ...         ...
# 5801            0.966         NaN
# 5802            1.036         8.5
# 5803            0.709         NaN
# 5804            2.186         NaN
# 5805            0.979        10.0
#
# [5806 rows x 15 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     King Arthur, accompanied by his squire, recrui...          1975
# 3     Brian Cohen is an average young Jewish man, bu...          1979
# 4     12-year-old Regan MacNeil begins to adapt an e...          1973
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# 2                   PG       91              ['comedy', 'fantasy']
# 3                    R       94                         ['comedy']
# 4                    R      133                         ['horror']
# ...                ...      ...                                ...
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']      1.0         NaN         NaN         NaN
# 1                  ['US']      NaN   tt0075314         8.3    795222.0
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 3                  ['GB']      NaN   tt0079470         8.0    392419.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# ...                   ...      ...         ...         ...         ...
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 1              27.612         8.2
# 2              18.216         7.8
# 3              17.505         7.8
# 4              95.337         7.7
# ...               ...         ...
# 5801            0.966         NaN
# 5802            1.036         8.5
# 5803            0.709         NaN
# 5804            2.186         NaN
# 5805            0.979        10.0
#
# [5806 rows x 15 columns]>

# %%
df.shape
# Out:
# (5806, 15)

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06
#
#        tmdb_popularity   tmdb_score
# count      5712.000000  5488.000000
# mean         22.525660     6.818039
# std          68.849177     1.171560
# min           0.009442     0.500000
# 25%           3.155250     6.100000
# 50%           7.478000     6.900000
# 75%          17.775750     7.500000
# max        1823.374000    10.000000

# %%
df.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# tmdb_popularity           94
# tmdb_score               318
# dtype: int64

# %%
df1 = df.dropna(subset=["title","description"])

# %%
df1= df1.drop(["seasons"],axis=1)

# %%
df1
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     King Arthur, accompanied by his squire, recrui...          1975
# 3     Brian Cohen is an average young Jewish man, bu...          1979
# 4     12-year-old Regan MacNeil begins to adapt an e...          1973
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# 2                   PG       91              ['comedy', 'fantasy']
# 3                    R       94                         ['comedy']
# 4                    R      133                         ['horror']
# ...                ...      ...                                ...
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']         NaN         NaN         NaN
# 1                  ['US']   tt0075314         8.3    795222.0
# 2                  ['GB']   tt0071853         8.2    530877.0
# 3                  ['GB']   tt0079470         8.0    392419.0
# 4                  ['US']   tt0070047         8.1    391942.0
# ...                   ...         ...         ...         ...
# 5801               ['NG']  tt13857480         6.9        39.0
# 5802                   []         NaN         NaN         NaN
# 5803         ['NG', 'CA']  tt14620732         6.5        32.0
# 5804                   []  tt10168094         6.2         9.0
# 5805                   []  tt13711094         8.8        16.0
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 1              27.612         8.2
# 2              18.216         7.8
# 3              17.505         7.8
# 4              95.337         7.7
# ...               ...         ...
# 5801            0.966         NaN
# 5802            1.036         8.5
# 5803            0.709         NaN
# 5804            2.186         NaN
# 5805            0.979        10.0
#
# [5788 rows x 14 columns]

# %%
df1.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description                0
# release_year               0
# age_certification       2603
# runtime                    0
# genres                     0
# production_countries       0
# imdb_id                  434
# imdb_score               510
# imdb_votes               525
# tmdb_popularity           89
# tmdb_score               309
# dtype: int64

# %%
df1.shape
# Out:
# (5788, 14)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
df1.fillna(method="bfill",inplace=True)

# %%
df1["type"]=le.fit_transform(df1["type"])
df1["age_certification"]= le.fit_transform(df1["age_certification"])

# %%
df1
# Out:
#              id                                title  type  \
# 0      ts300399  Five Came Back: The Reference Films     1
# 1       tm84618                          Taxi Driver     0
# 2      tm127384      Monty Python and the Holy Grail     0
# 3       tm70993                        Life of Brian     0
# 4      tm190788                         The Exorcist     0
# ...         ...                                  ...   ...
# 5801  tm1014599                            Fine Wine     0
# 5802  tm1108171                       Edis Starlight     0
# 5803  tm1045018                                Clash     0
# 5804  tm1098060                       Shadow Parties     0
# 5805   ts271048   Mighty Little Bheem: Kite Festival     1
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     King Arthur, accompanied by his squire, recrui...          1975
# 3     Brian Cohen is an average young Jewish man, bu...          1979
# 4     12-year-old Regan MacNeil begins to adapt an e...          1973
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#       age_certification  runtime                             genres  \
# 0                     7       48                  ['documentation']
# 1                     4      113                 ['crime', 'drama']
# 2                     2       91              ['comedy', 'fantasy']
# 3                     4       94                         ['comedy']
# 4                     4      133                         ['horror']
# ...                 ...      ...                                ...
# 5801                 11      100               ['romance', 'drama']
# 5802                 11       74         ['music', 'documentation']
# 5803                 11       88                ['family', 'drama']
# 5804                 11      116             ['action', 'thriller']
# 5805                 11        0  ['family', 'comedy', 'animation']
#
#      production_countries     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']   tt0075314         8.3    795222.0
# 1                  ['US']   tt0075314         8.3    795222.0
# 2                  ['GB']   tt0071853         8.2    530877.0
# 3                  ['GB']   tt0079470         8.0    392419.0
# 4                  ['US']   tt0070047         8.1    391942.0
# ...                   ...         ...         ...         ...
# 5801               ['NG']  tt13857480         6.9        39.0
# 5802                   []  tt14620732         6.5        32.0
# 5803         ['NG', 'CA']  tt14620732         6.5        32.0
# 5804                   []  tt10168094         6.2         9.0
# 5805                   []  tt13711094         8.8        16.0
#
#       tmdb_popularity  tmdb_score
# 0               0.600         8.2
# 1              27.612         8.2
# 2              18.216         7.8
# 3              17.505         7.8
# 4              95.337         7.7
# ...               ...         ...
# 5801            0.966         8.5
# 5802            1.036         8.5
# 5803            0.709        10.0
# 5804            2.186        10.0
# 5805            0.979        10.0
#
# [5788 rows x 14 columns]

# %%
df1.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
x = df1.drop(['type', 'title' , 'description','imdb_id', 'imdb_score', 'imdb_votes',
       'tmdb_score', 'production_countries','id','genres'],axis=1)
x
# Out:
#       release_year  age_certification  runtime  tmdb_popularity
# 0             1945                  7       48            0.600
# 1             1976                  4      113           27.612
# 2             1975                  2       91           18.216
# 3             1979                  4       94           17.505
# 4             1973                  4      133           95.337
# ...            ...                ...      ...              ...
# 5801          2021                 11      100            0.966
# 5802          2021                 11       74            1.036
# 5803          2021                 11       88            0.709
# 5804          2021                 11      116            2.186
# 5805          2021                 11        0            0.979
#
# [5788 rows x 4 columns]

# %%
y = df1["type"]
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 5801    0
# 5802    0
# 5803    0
# 5804    0
# 5805    1
# Name: type, Length: 5788, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

# %%
x_train = scale.fit_transform(x_train)

# %%
x_test = scale.transform(x_test)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
np.unique(y_pred,return_counts=True)
# Out:
# (array([0, 1]), array([938, 509], dtype=int64))

# %%
np.unique(y_test,return_counts=True)
# Out:
# (array([0, 1]), array([963, 484], dtype=int64))

# %%
plt.plot(y_test,y_pred)

# %%
df2= pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
df2
# Out:
#       Actual  Predicted
# 3874       0          0
# 5545       1          1
# 5128       1          1
# 3511       1          1
# 1161       0          0
# ...      ...        ...
# 2823       0          0
# 3116       0          0
# 2663       0          0
# 1075       1          1
# 4031       0          0
#
# [1447 rows x 2 columns]

# %%
df2.plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df2.plot(figsize=(15,15),kind='bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
df1.corr()
# Out:
#                        type  release_year  age_certification   runtime  \
# type               1.000000      0.118583           0.478527 -0.726793
# release_year       0.118583      1.000000           0.180343 -0.210652
# age_certification  0.478527      0.180343           1.000000 -0.389408
# runtime           -0.726793     -0.210652          -0.389408  1.000000
# imdb_score         0.288443     -0.102006           0.115550 -0.134728
# imdb_votes        -0.044679     -0.209384          -0.062789  0.128749
# tmdb_popularity    0.069442      0.025434           0.043624 -0.027233
# tmdb_score         0.398998      0.050473           0.213660 -0.261252
#
#                    imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# type                 0.288443   -0.044679         0.069442    0.398998
# release_year        -0.102006   -0.209384         0.025434    0.050473
# age_certification    0.115550   -0.062789         0.043624    0.213660
# runtime             -0.134728    0.128749        -0.027233   -0.261252
# imdb_score           1.000000    0.187760         0.024463    0.492886
# imdb_votes           0.187760    1.000000         0.192082    0.095346
# tmdb_popularity      0.024463    0.192082         1.000000    0.071236
# tmdb_score           0.492886    0.095346         0.071236    1.000000

# %%
sns.regplot(x="Actual",y="Predicted",data=df2,logistic=True)
# Out:
# <AxesSubplot:xlabel='Actual', ylabel='Predicted'>

# %%
from sklearn.metrics import accuracy_score,f1_score,mean_squared_error,mean_absolute_error
accuracy_score(y_test,y_pred)
# Out:
# 0.9136143745680718

# %%
f1_score(y_test,y_pred)
# Out:
# 0.8741188318227594

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.08638562543192813

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.08638562543192813

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x="Actual",y="Predicted",data=df2)
# Out:
# <AxesSubplot:xlabel='Actual', ylabel='Predicted'>

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[888,  75],
#        [ 50, 434]], dtype=int64)
